# %% [markdown]
# # 1 IMPORTING LIBRARIES

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D,Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 2 Importing Data

# %%
import os

main_dir = "\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data"

# SETTING TRAIN AND TEST DIRECTORY
train_dir = os.path.join(main_dir, "train")
test_dir = os.path.join(main_dir, "test")

#SETING DIRECTORY FOR COVID AND NORMAL IMAGES DIRECTORY
train_covid_dir = os.path.join(train_dir, "COVID19")
train_normal_dir = os.path.join(train_dir, "NORMAL")

test_covid_dir = os.path.join(test_dir, "COVID19")
test_normal_dir = os.path.join(test_dir, "NORMAL")

# %%
# MAKING SEPERATE FILES : 
train_covid_names = os.listdir(train_covid_dir)
train_normal_names = os.listdir(train_normal_dir)

test_covid_names = os.listdir(test_covid_dir)
test_normal_names = os.listdir(test_normal_dir)

# %% [markdown]
# # 3 PERFORMING DATA VISUALIZATION

# %%
import matplotlib.image as mpimg

rows = 4
columns = 4

fig = plt.gcf()
fig.set_size_inches(12,12)

covid_img = [os.path.join(train_covid_dir, filename) for filename in train_covid_names[0:8]]
normal_img = [os.path.join(train_normal_dir, filename) for filename in train_normal_names[0:8]]

print(covid_img)
print(normal_img)

merged_img = covid_img + normal_img

for i, img_path in enumerate(merged_img):
  title = img_path.split("\\", 12)[6]
  plot = plt.subplot(rows, columns, i+1)
  plot.axis("Off")
  img = mpimg.imread(img_path)
  plot.set_title(title, fontsize = 8)
  plt.imshow(img, cmap= "gray")

plt.show()
# Out:
# ['\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data\\train\\COVID19\\COVID-19 (1).jpeg', '\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data\\train\\COVID19\\COVID-19 (1).png', '\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data\\train\\COVID19\\COVID-19 (10).jpeg', '\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data\\train\\COVID19\\COVID-19 (101).jpg', '\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data\\train\\COVID19\\COVID-19 (107).jpg', '\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data\\train\\COVID19\\COVID-19 (11).jpeg', '\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data\\train\\COVID19\\COVID-19 (11).jpg', '\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data\\train\\COVID19\\COVID-19 (12).jpeg']
# ['\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data\\train\\NORMAL\\NORMAL(0).jpg', '\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data\\train\\NORMAL\\NORMAL(1).jpg', '\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data\\train\\NORMAL\\NORMAL(100).jpg', '\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data\\train\\NORMAL\\NORMAL(1000).jpg', '\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data\\train\\NORMAL\\NORMAL(1002).jpg', '\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data\\train\\NORMAL\\NORMAL(1005).jpg', '\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data\\train\\NORMAL\\NORMAL(1006).jpg', '\\Users\\Ajinkya\\OneDrive\\Documents\\Final Year Project\\Family-Doctor-Smart-Disease-Predictor\\Chext-X-ray-Images-Data-Set-main\\DataSet\\Data\\train\\NORMAL\\NORMAL(1007).jpg']

# %% [markdown]
# # 4 DATA PREPROCESSING AND AUGMENTATION

# %%
# CREATING TRAINING, TESTING AND VALIDATION BATCHES

dgen_train = ImageDataGenerator(rescale = 1./255,
                                validation_split = 0.2,
                                zoom_range = 0.2,
                                horizontal_flip = True)

dgen_validation = ImageDataGenerator(rescale = 1./255,
                                     )

dgen_test = ImageDataGenerator(rescale = 1./255,
                              )

train_generator = dgen_train.flow_from_directory(train_dir,
                                                 target_size = (150, 150), 
                                                 subset = 'training',
                                                 batch_size = 32,
                                                 class_mode = 'binary')
validation_generator = dgen_train.flow_from_directory(train_dir,
                                                      target_size = (150, 150), 
                                                      subset = "validation", 
                                                      batch_size = 32, 
                                                      class_mode = "binary")
test_generator = dgen_test.flow_from_directory(test_dir,
                                               target_size = (150, 150), 
                                               batch_size = 32, 
                                               class_mode = "binary")
# Out:
# Found 1449 images belonging to 2 classes.
# Found 362 images belonging to 2 classes.
# Found 484 images belonging to 2 classes.

# %%
print("Class Labels are: ", train_generator.class_indices)
print("Image shape is : ", train_generator.image_shape)
# Out:
# Class Labels are:  {'COVID19': 0, 'NORMAL': 1}
# Image shape is :  (150, 150, 3)

# %% [markdown]
# # 5 BUILDING CONVOLUTIONAL NEURAL NETWORK MODEL

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D

model = Sequential()

# 1) CONVOLUTIONAL LAYER - 1
model.add(Conv2D(32, (5,5), padding = "same", activation = "relu", input_shape = train_generator.image_shape))

# 2) POOLING LAYER - 1
model.add(MaxPooling2D(pool_size=(2,2)))

# 3) DROPOUT LAYER -2
model.add(Dropout(0.5))

# 4) CONVOLUTIONAL LAYER - 2
model.add(Conv2D(64, (5,5), padding = "same", activation = "relu"))

# 5) POOLING LAYER - 2
model.add(MaxPooling2D(pool_size=(2,2)))

# 6) DROPOUT LAYER - 2
model.add(Dropout(0.5))

# 7) FLATTENING LAYER TO 2D SHAPE
model.add(Flatten())

# 8) ADDING A DENSE LAYER
model.add(Dense(256, activation = 'relu'))

# 9 DROPOUT LAYER - 3
model.add(Dropout(0.5))

# 10) FINAL OUTPUT LAYER
model.add(Dense(1, activation = 'sigmoid'))

### PRINTING MODEL SUMMARY
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      2432
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  dropout (Dropout)           (None, 75, 75, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        51264
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 37, 37, 64)        0
#
#  flatten (Flatten)           (None, 87616)             0
#
#  dense (Dense)               (None, 256)               22429952
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 22,483,905
# Trainable params: 22,483,905
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 6 COMPILING AND TRAINING THE NEURAL NETWORK MODEL

# %%
# COMPILING THE MODEL

model.compile(Adam(learning_rate = 0.001), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# TRAINING THE MODEL
history = model.fit(train_generator, 
                    epochs = 35, 
                    validation_data = validation_generator)
# Out:
# Epoch 1/35
# 46/46 [==============================] - 214s 5s/step - loss: 0.9574 - accuracy: 0.7654 - val_loss: 0.3111 - val_accuracy: 0.8370
# Epoch 2/35
# 46/46 [==============================] - 141s 3s/step - loss: 0.2447 - accuracy: 0.9103 - val_loss: 0.1616 - val_accuracy: 0.9503
# Epoch 3/35
# 46/46 [==============================] - 140s 3s/step - loss: 0.1770 - accuracy: 0.9372 - val_loss: 0.2266 - val_accuracy: 0.9337
# Epoch 4/35
# 46/46 [==============================] - 144s 3s/step - loss: 0.1351 - accuracy: 0.9538 - val_loss: 0.1130 - val_accuracy: 0.9696
# Epoch 5/35
# 46/46 [==============================] - 125s 3s/step - loss: 0.1229 - accuracy: 0.9551 - val_loss: 0.1116 - val_accuracy: 0.9530
# Epoch 6/35
# 46/46 [==============================] - 107s 2s/step - loss: 0.1369 - accuracy: 0.9531 - val_loss: 0.1169 - val_accuracy: 0.9724
# Epoch 7/35
# 46/46 [==============================] - 112s 2s/step - loss: 0.1181 - accuracy: 0.9655 - val_loss: 0.0910 - val_accuracy: 0.9724
# Epoch 8/35
# 46/46 [==============================] - 103s 2s/step - loss: 0.1185 - accuracy: 0.9648 - val_loss: 0.1754 - val_accuracy: 0.9530
# Epoch 9/35
# 46/46 [==============================] - 100s 2s/step - loss: 0.1410 - accuracy: 0.9476 - val_loss: 0.1521 - val_accuracy: 0.9337
# Epoch 10/35
# 46/46 [==============================] - 99s 2s/step - loss: 0.1261 - accuracy: 0.9565 - val_loss: 0.1534 - val_accuracy: 0.9475
# Epoch 11/35
# 46/46 [==============================] - 99s 2s/step - loss: 0.1212 - accuracy: 0.9565 - val_loss: 0.1156 - val_accuracy: 0.9392
# Epoch 12/35
# 46/46 [==============================] - 99s 2s/step - loss: 0.1023 - accuracy: 0.9662 - val_loss: 0.0893 - val_accuracy: 0.9751
# Epoch 13/35
# 46/46 [==============================] - 103s 2s/step - loss: 0.0889 - accuracy: 0.9676 - val_loss: 0.0989 - val_accuracy: 0.9669
# Epoch 14/35
# 46/46 [==============================] - 100s 2s/step - loss: 0.0921 - accuracy: 0.9683 - val_loss: 0.0964 - val_accuracy: 0.9669
# Epoch 15/35
# 46/46 [==============================] - 100s 2s/step - loss: 0.0856 - accuracy: 0.9717 - val_loss: 0.0862 - val_accuracy: 0.9530
# Epoch 16/35
# 46/46 [==============================] - 100s 2s/step - loss: 0.0671 - accuracy: 0.9814 - val_loss: 0.1159 - val_accuracy: 0.9558
# Epoch 17/35
# 46/46 [==============================] - 101s 2s/step - loss: 0.0720 - accuracy: 0.9779 - val_loss: 0.0681 - val_accuracy: 0.9807
# Epoch 18/35
# 46/46 [==============================] - 99s 2s/step - loss: 0.0556 - accuracy: 0.9807 - val_loss: 0.0845 - val_accuracy: 0.9751
# Epoch 19/35
# 46/46 [==============================] - 100s 2s/step - loss: 0.0701 - accuracy: 0.9738 - val_loss: 0.0867 - val_accuracy: 0.9669
# Epoch 20/35
# 46/46 [==============================] - 99s 2s/step - loss: 0.0644 - accuracy: 0.9779 - val_loss: 0.0796 - val_accuracy: 0.9641
# Epoch 21/35
# 46/46 [==============================] - 104s 2s/step - loss: 0.0667 - accuracy: 0.9800 - val_loss: 0.0886 - val_accuracy: 0.9724
# Epoch 22/35
# 46/46 [==============================] - 147s 3s/step - loss: 0.0904 - accuracy: 0.9752 - val_loss: 0.0908 - val_accuracy: 0.9779
# Epoch 23/35
# 46/46 [==============================] - 168s 4s/step - loss: 0.0634 - accuracy: 0.9807 - val_loss: 0.0677 - val_accuracy: 0.9724
# Epoch 24/35
# 46/46 [==============================] - 166s 4s/step - loss: 0.0603 - accuracy: 0.9779 - val_loss: 0.0805 - val_accuracy: 0.9751
# Epoch 25/35
# 46/46 [==============================] - 160s 3s/step - loss: 0.0541 - accuracy: 0.9807 - val_loss: 0.0594 - val_accuracy: 0.9890
# Epoch 26/35
# 46/46 [==============================] - 161s 3s/step - loss: 0.0507 - accuracy: 0.9834 - val_loss: 0.0841 - val_accuracy: 0.9751
# Epoch 27/35
# 46/46 [==============================] - 153s 3s/step - loss: 0.0413 - accuracy: 0.9841 - val_loss: 0.0772 - val_accuracy: 0.9807
# Epoch 28/35
# 46/46 [==============================] - 173s 4s/step - loss: 0.0485 - accuracy: 0.9834 - val_loss: 0.0689 - val_accuracy: 0.9807
# Epoch 29/35
# 46/46 [==============================] - 165s 4s/step - loss: 0.0570 - accuracy: 0.9772 - val_loss: 0.0819 - val_accuracy: 0.9779
# Epoch 30/35
# 46/46 [==============================] - 137s 3s/step - loss: 0.0431 - accuracy: 0.9862 - val_loss: 0.0492 - val_accuracy: 0.9890
# Epoch 31/35
# 46/46 [==============================] - 133s 3s/step - loss: 0.0506 - accuracy: 0.9793 - val_loss: 0.0572 - val_accuracy: 0.9751
# Epoch 32/35
# 46/46 [==============================] - 132s 3s/step - loss: 0.0389 - accuracy: 0.9869 - val_loss: 0.0677 - val_accuracy: 0.9779
# Epoch 33/35
# 46/46 [==============================] - 131s 3s/step - loss: 0.0404 - accuracy: 0.9848 - val_loss: 0.0962 - val_accuracy: 0.9669
# Epoch 34/35
# 46/46 [==============================] - 107s 2s/step - loss: 0.0653 - accuracy: 0.9786 - val_loss: 0.0835 - val_accuracy: 0.9558
# Epoch 35/35
# 46/46 [==============================] - 120s 3s/step - loss: 0.0772 - accuracy: 0.9738 - val_loss: 0.0769 - val_accuracy: 0.9751

# %% [markdown]
# # 7 PERFORMING EVALUATION

# %%
# KEYS OF HISTORY OBJECT
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# PLOT GRAPH BETWEEN TRAINING AND VALIDATION LOSS
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training', 'Validation'])
plt.title("Training and validation losses")
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# PLOT GRAPH BETWEEN TRAINING AND VALIDATION ACCURACY
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Training', 'Validation'])
plt.title("Training and validation accuracy")
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# GETTING TEST ACCURACY AND LOSS

test_loss, test_acc = model.evaluate(test_generator)
print("Test Set Loss : ", test_loss)
print("Test Set Accuracy : ", test_acc)
# Out:
# 16/16 [==============================] - 35s 2s/step - loss: 0.1229 - accuracy: 0.9463
# Test Set Loss :  0.12289711833000183
# Test Set Accuracy :  0.9462810158729553

# %% [markdown]
# # Creating Model

# %%
model.save("models/covid.h5")
